# %%
import pandas as pd

# %%
data = {
    'name': ['Sheldon', 'Penny', 'Amy', 'Penny', 'Raj', 'Sheldon'],
    'age': [42, 24, 31, 29, 37, 40],
    'gender': ['male', 'female', 'female', 'female', 'male', 'male'],
    'education': ['Under-Graduate', 'Diploma ' , 'Post-Graduate', 'Diploma ', 'Under-Graduate', 'Post-Graduate'],
    'place' : ['malappuram', 'calicut', 'kochi', 'malappuram', 'calicut', 'kochi']
    }

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#       name  age  gender       education       place
# 0  Sheldon   42    male  Under-Graduate  malappuram
# 1    Penny   24  female        Diploma      calicut
# 2      Amy   31  female   Post-Graduate       kochi
# 3    Penny   29  female        Diploma   malappuram
# 4      Raj   37    male  Under-Graduate     calicut
# 5  Sheldon   40    male   Post-Graduate       kochi

# %%
df.dtypes
# Out:
# name         object
# age           int64
# gender       object
# education    object
# place        object
# dtype: object

# %% [markdown]
# # Method 1:Using replace()method

# %%
df1=df
df1["gender"].replace(["male","female"],[0,1],inplace=True)

# %%
df1
# Out:
#       name  age  gender       education       place
# 0  Sheldon   42       0  Under-Graduate  malappuram
# 1    Penny   24       1        Diploma      calicut
# 2      Amy   31       1   Post-Graduate       kochi
# 3    Penny   29       1        Diploma   malappuram
# 4      Raj   37       0  Under-Graduate     calicut
# 5  Sheldon   40       0   Post-Graduate       kochi

# %% [markdown]
# # Method 2:Using get_dummies()

# %%
df["education"].unique()
# Out:
# array(['Under-Graduate', 'Diploma ', 'Post-Graduate'], dtype=object)

# %%
# get the dummies and store it in a variable
dummies=pd.get_dummies(df["education"])
dummies
# Out:
#    Diploma   Post-Graduate  Under-Graduate
# 0     False          False            True
# 1      True          False           False
# 2     False           True           False
# 3      True          False           False
# 4     False          False            True
# 5     False           True           False

# %%
#get the dummies with integer values and store it in a variable
dummies=pd.get_dummies(df["education"]).astype(int)
dummies
# Out:
#    Diploma   Post-Graduate  Under-Graduate
# 0         0              0               1
# 1         1              0               0
# 2         0              1               0
# 3         1              0               0
# 4         0              0               1
# 5         0              1               0

# %%
# concatenate the dummies to original DataFrame
df2=pd.concat([df,dummies],axis="columns")
df2
# Out:
#       name  age  gender       education       place  Diploma   Post-Graduate  \
# 0  Sheldon   42       0  Under-Graduate  malappuram         0              0
# 1    Penny   24       1        Diploma      calicut         1              0
# 2      Amy   31       1   Post-Graduate       kochi         0              1
# 3    Penny   29       1        Diploma   malappuram         1              0
# 4      Raj   37       0  Under-Graduate     calicut         0              0
# 5  Sheldon   40       0   Post-Graduate       kochi         0              1
#
#    Under-Graduate
# 0               1
# 1               0
# 2               0
# 3               0
# 4               1
# 5               0

# %%
# drop the original variable
df2.drop(["education"],axis="columns",inplace=True)
# print the dataframe
print(df2)
# Out:
#       name  age  gender       place  Diploma   Post-Graduate  Under-Graduate
# 0  Sheldon   42       0  malappuram         0              0               1
# 1    Penny   24       1     calicut         1              0               0
# 2      Amy   31       1       kochi         0              1               0
# 3    Penny   29       1  malappuram         1              0               0
# 4      Raj   37       0     calicut         0              0               1
# 5  Sheldon   40       0       kochi         0              1               0

# %% [markdown]
# # Method 3:label encoding

# %%
# importing labelencoding from sklearn library from preprocessinng module.
from sklearn.preprocessing import LabelEncoder

# creating a instance of label encorder
le=LabelEncoder()

# %%
df3=df2
df3["name"]=le.fit_transform(df2["name"])
print(df3)
# Out:
#    name  age  gender       place  Diploma   Post-Graduate  Under-Graduate
# 0     3   42       0  malappuram         0              0               1
# 1     1   24       1     calicut         1              0               0
# 2     0   31       1       kochi         0              1               0
# 3     1   29       1  malappuram         1              0               0
# 4     2   37       0     calicut         0              0               1
# 5     3   40       0       kochi         0              1               0

# %%
df4=df3
df4["place"]=le.fit_transform(df2["place"])
print(df4)
# Out:
#    name  age  gender  place  Diploma   Post-Graduate  Under-Graduate
# 0     3   42       0      2         0              0               1
# 1     1   24       1      0         1              0               0
# 2     0   31       1      1         0              1               0
# 3     1   29       1      2         1              0               0
# 4     2   37       0      0         0              0               1
# 5     3   40       0      1         0              1               0

# %%
df4.dtypes
# Out:
# name              int64
# age               int64
# gender            int64
# place             int64
# Diploma           int64
# Post-Graduate     int64
# Under-Graduate    int64
# dtype: object
