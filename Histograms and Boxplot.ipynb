# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the iris dataset
from sklearn.datasets import load_iris
iris=load_iris()
iris_df=pd.DataFrame(iris.data,columns=iris.feature_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # Histograms

# %%
plt.hist(iris_df['sepal length (cm)'],color='lightblue',edgecolor='black')
plt.title('histogram of sepal length (cm)')
# Out:
# Text(0.5, 1.0, 'histogram of sepal length (cm)')

# %%
# Distribution
sns.histplot(iris_df['sepal length (cm)'],kde=True)
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Count'>

# %%
plt.hist(iris_df['sepal width (cm)'],color='blue',edgecolor='black')
plt.title('histogram of sepal length (cm)')
# Out:
# Text(0.5, 1.0, 'histogram of sepal length (cm)')

# %%
# Plotting histogram for each feature
iris_df.hist(edgecolor='black')
plt.suptitle('Histograms of Iris Dataset Features',fontsize=16)
plt.show()

# %% [markdown]
# Here are some inferences that can be drawn from the histograms for the Iris dataset:
#
# ### **1. Sepal Length**:
# - The data appears to be somewhat normally distributed, but with a slight right skew. The majority of the values are clustered between 5 and 6 cm.
#
#
# ### **2. Sepal Width**:
# - The distribution is not normal; it has two prominent peaks, indicating a **bimodal distribution**. The data points are spread more broadly, ranging from 2 cm to 4 cm.
#
#
# ### **3. Petal Length**:
# - This feature shows a **strong right-skew**. The majority of the data points are concentrated on the lower end (around 1 to 2 cm), with fewer data points in the higher range.
#
#
# ### **4. Petal Width**:
# - Similar to petal length, the distribution is **right-skewed**, with most values clustered between 0.1 cm and 0.6 cm.
#
#
# ### **Overall Insights**:
# - **Skewness**: Both petal length and petal width are right-skewed, indicating that most Iris flowers in the dataset have shorter petals.
# - **Bimodal distribution**: Sepal width has a bimodal distribution, which might indicate that different species of Iris exhibit different sepal widths.

# %% [markdown]
# # load_wine dataset

# %%
# load the wine dataset
from sklearn.datasets import load_wine
wine=load_wine()
wine_df=pd.DataFrame(wine.data,columns=wine.feature_names)
wine_df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
#load_wine
wine_df.hist(edgecolor='black',figsize=(19,10))
plt.suptitle('Histograms of Iris Dataset Features',fontsize=16)
plt.show()

# %% [markdown]
# 1. alcohol
# * The distribution is  normal
# * most value is 12 to 14

# %% [markdown]
# 2. malic_acid
# * most value is 0 to 2
# * its is strong right skew

# %% [markdown]
# 3.ash
# * it is normal distribution
# * most value at 2.0 to 2.5

# %% [markdown]
# 4.alcalinity_of_ash
# * normal distribution,but with a slight right skew
# * most value 15 to 20

# %% [markdown]
# 5.magnesium
# * it is right skew
# * most value 80 to 100

# %%
# plotting boxplot for each feature
wine_df.plot(kind='box', subplots=True, layout=(3,5), figsize=(12,8), color='blue')
plt.suptitle('boxplot of wine dataset features', fontsize=16)
plt.show()

# %% [markdown]
# # Boxplot

# %%
print(np.quantile(iris_df['sepal length (cm)'],[0.25,0.5,0.75]))
# o.25 means Q1(25%)
# 0.5 means Q2/median(50%)
# 0.75 means Q3(75%)
# Out:
# [5.1 5.8 6.4]

# %%
plt.boxplot(iris_df['sepal length (cm)'], vert=False, patch_artist=True)
plt.title('Boxplot of sepal length')
plt.xlabel('value')
# Out:
# Text(0.5, 0, 'value')

# %%
plt.boxplot(iris_df['petal length (cm)'], vert=False, patch_artist=True)
plt.title('Boxplot of petal length')
plt.xlabel('value')
# Out:
# Text(0.5, 0, 'value')

# %%
# plotting boxplot for each feature
iris_df.plot(kind='box', subplots=True, layout=(1,4), figsize=(12,6), color='blue')
plt.suptitle('boxplot of iris dataset features', fontsize=16)
plt.show()

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# The describe() function in a pandas DataFrame provides a quick overview of the statistical properties of the data.
#
# It generates descriptive statistics for each numerical column in the DataFrame including
# * Count: Number of non-null entries in each column.
# * Mean: Average value of the column.
# * Standard Deviation (std): Measure of the spread or dispersion of the values in the column.
# * Minimum (min): The smallest value in the column.
# * 25th Percentile (25%): Value below which 25% of the data falls (also known as the first quartile).
# * 50th Percentile (50%): Median value of the column, below which 50% of the data falls.
# * 75th Percentile (75%): Value below which 75% of the data falls (also known as the third quartile).
# * Maximum (max): The largest value in the column.
#
#
#
#
#
# - **Outliers**: The boxplots reveal that there are a few outliers in the sepal width. The most of the distributions are right-skewed. The interquartile range (IQR) is narrower for Sepal Width compared to the other features.
